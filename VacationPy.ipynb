# %%
# Import the required libraries
import hvplot.pandas
import pandas as pd

# %%
# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# %%
# Store the CSV you saved created in part one into a DataFrame.
city_data_df = pd.read_csv("weather_data/cities.csv")
city_data_df.head()
# Out:
#    City_ID            City Country                 Date      Lat       Lng  \
# 0        0    Puerto Ayora      EC  2022-11-27 22:55:29  -0.7393  -90.3518
# 1        1          Vostok      RU  2022-11-27 22:55:30  46.4856  135.8833
# 2        2          Hobart      AU  2022-11-27 22:55:30 -42.8794  147.3294
# 3        3          Avarua      CK  2022-11-27 22:55:31 -21.2078 -159.7750
# 4        4  Saint-Philippe      RE  2022-11-27 22:55:31 -21.3585   55.7679
#
#     Temp  Min Temp  Max Temp Current Description   Current Details  Humidity  \
# 0  70.56     70.56     76.96              Clouds  scattered clouds        88
# 1   5.76      5.76      5.76              Clouds     broken clouds        92
# 2  58.12     54.27     61.27              Clouds        few clouds        59
# 3  80.65     80.65     80.65              Clouds        few clouds        61
# 4  71.19     69.12     71.19              Clouds  scattered clouds        75
#
#    Cloudiness  Wind Speed
# 0          46       10.00
# 1          63        3.69
# 2          20       13.80
# 3          20       17.27
# 4          30        3.89

# %%
# Get the data types.
city_data_df.dtypes
# Out:
# City_ID                  int64
# City                    object
# Country                 object
# Date                    object
# Lat                    float64
# Lng                    float64
# Temp                   float64
# Min Temp               float64
# Max Temp               float64
# Current Description     object
# Current Details         object
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# dtype: object

# %%
# Configure the map plot_1
map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM"
)

# %%
# Display the map plot_1
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]

# %%
# Configure the map plot_2
map_plot_2 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500
)

# Display the map plot
map_plot_2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]

# %%
# Configure the map plot_3
map_plot_3 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Max Temp",
    scale = 0.5,
    color = "City"
)

# Display the map plot
map_plot_3
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp)

# %%
# Configure the map plot_4
map_plot_4 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "EsriNatGeo",
    frame_width = 700,
    frame_height = 500,
    size = "Max Temp",
    scale = 0.5,
    color = "City"
)

# Display the map plot
map_plot_4
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp)

# %%
# Ask the customer to add a minimum and maximum temperature value.
min_temp = float(input("What is the minimum temperature you would like for your trip? "))
max_temp = float(input("What is the maximum temperature you would like for your trip? "))
# Out:
# What is the minimum temperature you would like for your trip? 75
# What is the maximum temperature you would like for your trip? 90

# %%
preferred_cities_df = city_data_df.loc[
    (city_data_df["Max Temp"] <= max_temp) & (city_data_df["Max Temp"] >= min_temp)
]
preferred_cities_df.head(10)
# Out:
#     City_ID            City Country                 Date      Lat       Lng  \
# 0         0    Puerto Ayora      EC  2022-11-27 22:55:29  -0.7393  -90.3518
# 3         3          Avarua      CK  2022-11-27 22:55:31 -21.2078 -159.7750
# 7         7        Celestun      MX  2022-11-27 22:55:32  20.8667  -90.4000
# 18       18         Kahului      US  2022-11-27 22:55:37  20.8947 -156.4700
# 21       21  Ciudad Bolivar      VE  2022-11-27 22:55:38   8.1222  -63.5497
# 23       23            Hilo      US  2022-11-27 22:51:15  19.7297 -155.0900
# 25       25            Poya      NC  2022-11-27 22:55:39 -21.3500  165.1500
# 26       26          Atuona      PF  2022-11-27 22:51:42  -9.8000 -139.0333
# 31       31         Rikitea      PF  2022-11-27 22:55:41 -23.1203 -134.9692
# 35       35           Kapaa      US  2022-11-27 22:55:42  22.0752 -159.3190
#
#      Temp  Min Temp  Max Temp Current Description       Current Details  \
# 0   70.56     70.56     76.96              Clouds      scattered clouds
# 3   80.65     80.65     80.65              Clouds            few clouds
# 7   80.73     80.73     80.73              Clouds      scattered clouds
# 18  78.39     77.85     80.96              Clouds       overcast clouds
# 21  77.09     77.09     77.09                Rain  heavy intensity rain
# 23  78.84     76.62     80.33               Clear             clear sky
# 25  85.39     85.39     85.39              Clouds         broken clouds
# 26  77.94     77.94     77.94               Clear             clear sky
# 31  75.78     75.78     75.78              Clouds         broken clouds
# 35  77.18     75.18     80.58              Clouds       overcast clouds
#
#     Humidity  Cloudiness  Wind Speed
# 0         88          46       10.00
# 3         61          20       17.27
# 7         79          47       10.49
# 18        83         100        8.99
# 21        86         100       13.62
# 23        72           0       10.36
# 25        60          72        3.67
# 26        75           4       13.44
# 31        69          80        4.92
# 35        71          98        3.00

# %%
preferred_cities_df.count()
# Out:
# City_ID                141
# City                   141
# Country                141
# Date                   141
# Lat                    141
# Lng                    141
# Temp                   141
# Min Temp               141
# Max Temp               141
# Current Description    141
# Current Details        141
# Humidity               141
# Cloudiness             141
# Wind Speed             141
# dtype: int64

# %%
# Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = preferred_cities_df[["City", "Country", "Max Temp", "Lat", "Lng"]].copy()
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#               City Country  Max Temp      Lat       Lng Hotel Name
# 0     Puerto Ayora      EC     76.96  -0.7393  -90.3518
# 3           Avarua      CK     80.65 -21.2078 -159.7750
# 7         Celestun      MX     80.73  20.8667  -90.4000
# 18         Kahului      US     80.96  20.8947 -156.4700
# 21  Ciudad Bolivar      VE     77.09   8.1222  -63.5497
# 23            Hilo      US     80.33  19.7297 -155.0900
# 25            Poya      NC     85.39 -21.3500  165.1500
# 26          Atuona      PF     77.94  -9.8000 -139.0333
# 31         Rikitea      PF     75.78 -23.1203 -134.9692
# 35           Kapaa      US     80.58  22.0752 -159.3190

# %%
# Import the API key.
from config import geoapify_key

# %%
# Set initial parameters to search for a hotel.
radius = 5000
params = {
    "categories":"accommodation.hotel",
    "apiKey": geoapify_key,
}

# %%
 # Iterate through the hotel DataFrame

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # Get latitude and longitude from DataFrame.
    latitude = row["Lat"]
    longitude = row["Lng"]
    
    # Add the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set up the base URL for the Geoapify Places API.
    base_url = "https://api.geoapify.com/v2/places"

    # Make request and retrieve the JSON data by using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Get the first hotel from the results and store the name, if a hotel isn't found set the hotel name as "No hotel found".
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# Puerto Ayora - nearest hotel: Hostal La Mirada De Solitario George
# Avarua - nearest hotel: Paradise Inn
# Celestun - nearest hotel: Hotel Flamingo Playa
# Kahului - nearest hotel: Maui Seaside Hotel
# Ciudad Bolivar - nearest hotel: Paoca
# Hilo - nearest hotel: Dolphin Bay Hotel
# Poya - nearest hotel: No hotel found
# Atuona - nearest hotel: Pearl Resort
# Rikitea - nearest hotel: Chez Bianca & Benoit
# Kapaa - nearest hotel: Pono Kai Resort
# Butaritari - nearest hotel: No hotel found
# Cabo San Lucas - nearest hotel: Comfort Rooms
# Faanui - nearest hotel: Oa Oa Lodge
# Hithadhoo - nearest hotel: Pebbles Inn
# Bonthe - nearest hotel: No hotel found
# Hobyo - nearest hotel: No hotel found
# Isangel - nearest hotel: Tanna Lodge
# Mareeba - nearest hotel: The Gateway Hotel
# Bentiu - nearest hotel: No hotel found
# Itamaraca - nearest hotel: No hotel found
# Ambulu - nearest hotel: Hotel Ambulu
# Cayenne - nearest hotel: Central Hôtel
# Acapulco - nearest hotel: Hotel del Valle
# Bengkulu - nearest hotel: Dena Hotel
# San Luis - nearest hotel: Hotel Dos Venados
# Bathsheba - nearest hotel: Atlantis Hotel
# Vaini - nearest hotel: Keleti International Resort
# Wanning - nearest hotel: No hotel found
# Dingle - nearest hotel: No hotel found
# Vao - nearest hotel: Nataiwatch
# Auki - nearest hotel: No hotel found
# Santa Cruz Cabralia - nearest hotel: Campo Bahia Resort
# Rio Bueno - nearest hotel: No hotel found
# Kismayo - nearest hotel: Kismayo Hotel
# Alofi - nearest hotel: No hotel found
# Kavieng - nearest hotel: Kavieng Hotel
# Mineiros - nearest hotel: Hotel Dallas
# Tual - nearest hotel: Suita
# Namatanai - nearest hotel: Namatanai Hotel
# Georgetown - nearest hotel: Page 63 hostel
# Touros - nearest hotel: Pousada Atlântico
# Victoria - nearest hotel: 四季酒店 Four Seasons Hotel
# Sibolga - nearest hotel: Hotel Prima Indah
# Panaba - nearest hotel: No hotel found
# Eydhafushi - nearest hotel: No hotel found
# Sao Jose Da Coroa Grande - nearest hotel: Hotel do Sol
# Samarai - nearest hotel: No hotel found
# Alegrete - nearest hotel: Expresso Hotel
# Gorontalo - nearest hotel: Grand City Hotel
# Angoche - nearest hotel: Hotel Quirimbas
# Sumter - nearest hotel: No hotel found
# Arraial Do Cabo - nearest hotel: No hotel found
# Santa Rosa - nearest hotel: JARS RESORT
# Dubai - nearest hotel: Holiday Inn Bur Dubai - Embassy District
# Vanimo - nearest hotel: CBC Guesthouse
# Maragogi - nearest hotel: Pousada Mariluz
# Hambantota - nearest hotel: Oasis Aurweda Resort Hambathota
# Coruripe - nearest hotel: No hotel found
# Mitsamiouli - nearest hotel: Hotel le Paradis
# Sandakan - nearest hotel: Rose Guesthouse
# Tabou - nearest hotel: hôtel le rochet
# Indramayu - nearest hotel: No hotel found
# Anahuac - nearest hotel: Hotel Anáhuac
# Cairns - nearest hotel: Cairns Queens Court Accommodation
# Beihai - nearest hotel: Pearl Bay Seaview Hotel
# Cocorit - nearest hotel: No hotel found
# Lorengau - nearest hotel: Seeadler Bay Hotel
# Kuala Terengganu - nearest hotel: Uncle Homestay
# Ende - nearest hotel: LCR Hotel
# Karratha - nearest hotel: Karratha International Hotel
# Puerto Escondido - nearest hotel: Hotel Barlovento
# Catia La Mar - nearest hotel: Posada La Parada
# Takoradi - nearest hotel: Hillcrest
# Les Cayes - nearest hotel: No hotel found
# Kiunga - nearest hotel: No hotel found
# Port-Gentil - nearest hotel: Tara-Mé
# Kuching - nearest hotel: Hotel Samudera
# Bubaque - nearest hotel: Chez Julio
# Honiara - nearest hotel: King Solomon Hotel
# San Patricio - nearest hotel: No hotel found
# Uberlandia - nearest hotel: Hotel Presidente
# Oistins - nearest hotel: The Abidah By Accra
# Codajas - nearest hotel: No hotel found
# Pangai - nearest hotel: Billy's Place
# Pocone - nearest hotel: Tuiuiu
# Sawtell - nearest hotel: Boambee Bay Resort
# San Miguel - nearest hotel: Continental Plaza Hotel
# Boyolangu - nearest hotel: No hotel found
# Coahuayana - nearest hotel: No hotel found
# Gigmoto - nearest hotel: No hotel found
# Raga - nearest hotel: No hotel found
# Morondava - nearest hotel: Hotel Sharon Menabe
# Hervey Bay - nearest hotel: Hervey Bay Hotel
# Poum - nearest hotel: No hotel found
# Katherine - nearest hotel: No hotel found
# Brownsville - nearest hotel: Cameron Hotel
# Mango - nearest hotel: Hilton Garden Inn Tampa East/Brandon
# Arroio Do Meio - nearest hotel: Hotel Central
# Sola - nearest hotel: No hotel found
# Kieta - nearest hotel: No hotel found
# Aden - nearest hotel: فندق قصر الجزيرة
# Kihei - nearest hotel: Maui Beach Resort
# Sao Filipe - nearest hotel: Bela Vista
# Pitimbu - nearest hotel: Pousada Brisa Mar
# Progreso - nearest hotel: Centro Vacacional Obrero CTM
# Harper - nearest hotel: No hotel found
# Camocim - nearest hotel: Hotel Dunas
# Kununurra - nearest hotel: Kununurra Country Club Resort
# Yaguajay - nearest hotel: Plaza
# Singaraja - nearest hotel: Hotel Sentral
# Baracoa - nearest hotel: Casa
# Kavaratti - nearest hotel: No hotel found
# Buluang - nearest hotel: No hotel found
# Goundam - nearest hotel: No hotel found
# Bucerias - nearest hotel: Royal Decameron Complex
# Pangoa - nearest hotel: No hotel found
# Port Macquarie - nearest hotel: The Observatory
# Pemangkat - nearest hotel: Hotel Kelapa Gading
# Ormond Beach - nearest hotel: Royal Floridian Resort
# San Policarpo - nearest hotel: No hotel found
# Lazaro Cardenas - nearest hotel: Hotel Sol del Pacífico
# Lamu - nearest hotel: Hotel Archipelago villa bed and breakfast
# Lanas - nearest hotel: White Beach Resort
# Acajutla - nearest hotel: Hotel Lara
# Phan Thiet - nearest hotel: Khách sạn Cà Ty
# Carutapera - nearest hotel: No hotel found
# Luanda - nearest hotel: Hotel Forum
# Balabac - nearest hotel: No hotel found
# Makakilo City - nearest hotel: Embassy Suites by Hilton Oahu Kapolei
# Barra Patuca - nearest hotel: No hotel found
# Kibala - nearest hotel: No hotel found
# Bandarbeyla - nearest hotel: No hotel found
# Ambon - nearest hotel: Hotel Hero
# Buala - nearest hotel: No hotel found
# Bac Lieu - nearest hotel: Khách sạn Bạc Liêu
# Pandan Niog - nearest hotel: No hotel found
# Tiarei - nearest hotel: No hotel found
# Ewa Beach - nearest hotel: Hampton Inn & Suites Oahu/Kapolei
# Nisia Floresta - nearest hotel: No hotel found
# Salug - nearest hotel: No hotel found
# Cienfuegos - nearest hotel: No hotel found
#                City Country  Max Temp      Lat       Lng  \
# 0      Puerto Ayora      EC     76.96  -0.7393  -90.3518
# 3            Avarua      CK     80.65 -21.2078 -159.7750
# 7          Celestun      MX     80.73  20.8667  -90.4000
# 18          Kahului      US     80.96  20.8947 -156.4700
# 21   Ciudad Bolivar      VE     77.09   8.1222  -63.5497
# ..              ...     ...       ...      ...       ...
# 547          Tiarei      PF     84.22 -17.5333 -149.3333
# 549       Ewa Beach      US     81.84  21.3156 -158.0072
# 552  Nisia Floresta      BR     81.41  -6.0911  -35.2086
# 553           Salug      PH     78.85   8.1147  122.7833
# 555      Cienfuegos      CU     77.43  22.1461  -80.4356
#
#                                Hotel Name
# 0    Hostal La Mirada De Solitario George
# 3                            Paradise Inn
# 7                    Hotel Flamingo Playa
# 18                     Maui Seaside Hotel
# 21                                  Paoca
# ..                                    ...
# 547                        No hotel found
# 549     Hampton Inn & Suites Oahu/Kapolei
# 552                        No hotel found
# 553                        No hotel found
# 555                        No hotel found
#
# [141 rows x 6 columns]

# %%
# Configure the map
hotel_map = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Max Temp",
    scale = 1,
    color = "City"
)

# Display the map plot
hotel_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Max Temp)
