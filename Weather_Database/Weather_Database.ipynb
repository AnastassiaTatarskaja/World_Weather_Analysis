# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 769

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        # YOUR CODE HERE       
            
        # Append the city information into the city_data list
        # YOUR CODE HERE
        
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_temp = city_weather["main"]["temp"]
        city_min_temp = city_weather["main"]["temp_min"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_main = city_weather["weather"][0]["main"]
        weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Temp": city_temp,
                          "Min Temp": city_min_temp,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_main,
                          "Current Details": weather_description,
                          "Country": city_country,
                          "Date": city_date})

    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bathsheba
# Processing Record 2 of Set 1 | cidreira
# Processing Record 3 of Set 1 | emerald
# Processing Record 4 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 5 of Set 1 | cape town
# Processing Record 6 of Set 1 | batagay-alyta
# Processing Record 7 of Set 1 | kaeo
# Processing Record 8 of Set 1 | castro
# Processing Record 9 of Set 1 | lebu
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | goderich
# Processing Record 12 of Set 1 | inhambane
# Processing Record 13 of Set 1 | avarua
# Processing Record 14 of Set 1 | ancud
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | klaksvik
# Processing Record 17 of Set 1 | slobodskoy
# Processing Record 18 of Set 1 | esperance
# Processing Record 19 of Set 1 | isangel
# Processing Record 20 of Set 1 | meulaboh
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | bluff
# Processing Record 23 of Set 1 | senador guiomard
# Processing Record 24 of Set 1 | roald
# Processing Record 25 of Set 1 | hilo
# Processing Record 26 of Set 1 | te anau
# Processing Record 27 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 1 | qaanaaq
# Processing Record 29 of Set 1 | yellowknife
# Processing Record 30 of Set 1 | ardahan
# Processing Record 31 of Set 1 | kismayo
# Processing Record 32 of Set 1 | chapais
# Processing Record 33 of Set 1 | dikson
# Processing Record 34 of Set 1 | bengkulu
# Processing Record 35 of Set 1 | cayenne
# Processing Record 36 of Set 1 | kudahuvadhoo
# Processing Record 37 of Set 1 | vaini
# Processing Record 38 of Set 1 | east london
# Processing Record 39 of Set 1 | norman wells
# Processing Record 40 of Set 1 | palora
# Processing Record 41 of Set 1 | trebinje
# Processing Record 42 of Set 1 | puerto madryn
# Processing Record 43 of Set 1 | staraya poltavka
# Processing Record 44 of Set 1 | el alto
# Processing Record 45 of Set 1 | vostok
# Processing Record 46 of Set 1 | atuona
# Processing Record 47 of Set 1 | thompson
# Processing Record 48 of Set 1 | nador
# Processing Record 49 of Set 1 | muri
# Processing Record 50 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 2 | mareeba
# Processing Record 2 of Set 2 | albany
# Processing Record 3 of Set 2 | zelenchukskaya
# Processing Record 4 of Set 2 | cabo san lucas
# Processing Record 5 of Set 2 | filingue
# Processing Record 6 of Set 2 | hithadhoo
# Processing Record 7 of Set 2 | tazovskiy
# Processing Record 8 of Set 2 | konstantinovka
# Processing Record 9 of Set 2 | carnarvon
# Processing Record 10 of Set 2 | tuktoyaktuk
# Processing Record 11 of Set 2 | sungurlu
# Processing Record 12 of Set 2 | jamestown
# Processing Record 13 of Set 2 | nebolchi
# Processing Record 14 of Set 2 | ribeira grande
# Processing Record 15 of Set 2 | tambopata
# Processing Record 16 of Set 2 | chokurdakh
# Processing Record 17 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 18 of Set 2 | mataura
# Processing Record 19 of Set 2 | hermanus
# Processing Record 20 of Set 2 | varhaug
# Processing Record 21 of Set 2 | arraial do cabo
# Processing Record 22 of Set 2 | longyearbyen
# Processing Record 23 of Set 2 | lagoa
# Processing Record 24 of Set 2 | zhuji
# Processing Record 25 of Set 2 | georgetown
# Processing Record 26 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 2 | tuatapere
# Processing Record 28 of Set 2 | upernavik
# Processing Record 29 of Set 2 | sistranda
# Processing Record 30 of Set 2 | lasa
# Processing Record 31 of Set 2 | kruisfontein
# Processing Record 32 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 33 of Set 2 | camacha
# Processing Record 34 of Set 2 | baykit
# Processing Record 35 of Set 2 | vardo
# Processing Record 36 of Set 2 | oudtshoorn
# Processing Record 37 of Set 2 | ambilobe
# Processing Record 38 of Set 2 | victoria
# Processing Record 39 of Set 2 | toora-khem
# Processing Record 40 of Set 2 | samur
# Processing Record 41 of Set 2 | uvat
# Processing Record 42 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 2 | inongo
# Processing Record 44 of Set 2 | lompoc
# Processing Record 45 of Set 2 | mola di bari
# Processing Record 46 of Set 2 | barcelos
# Processing Record 47 of Set 2 | peniche
# Processing Record 48 of Set 2 | majene
# Processing Record 49 of Set 2 | port moresby
# Processing Record 50 of Set 2 | kapaa
# Processing Record 1 of Set 3 | cockburn town
# Processing Record 2 of Set 3 | merauke
# Processing Record 3 of Set 3 | adrar
# Processing Record 4 of Set 3 | harper
# Processing Record 5 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 6 of Set 3 | panaba
# Processing Record 7 of Set 3 | clyde river
# Processing Record 8 of Set 3 | nome
# Processing Record 9 of Set 3 | port elizabeth
# Processing Record 10 of Set 3 | hobart
# Processing Record 11 of Set 3 | balykshi
# Processing Record 12 of Set 3 | ilulissat
# Processing Record 13 of Set 3 | mar del plata
# Processing Record 14 of Set 3 | mahebourg
# Processing Record 15 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 3 | kulhudhuffushi
# Processing Record 17 of Set 3 | kaliua
# Processing Record 18 of Set 3 | champerico
# Processing Record 19 of Set 3 | kenai
# Processing Record 20 of Set 3 | pevek
# Processing Record 21 of Set 3 | bandarbeyla
# Processing Record 22 of Set 3 | porto santo
# Processing Record 23 of Set 3 | lorengau
# Processing Record 24 of Set 3 | bredasdorp
# Processing Record 25 of Set 3 | itarema
# Processing Record 26 of Set 3 | karratha
# Processing Record 27 of Set 3 | pacific grove
# Processing Record 28 of Set 3 | kodiak
# Processing Record 29 of Set 3 | codrington
# Processing Record 30 of Set 3 | rawson
# Processing Record 31 of Set 3 | lovozero
# Processing Record 32 of Set 3 | port hardy
# Processing Record 33 of Set 3 | khatanga
# Processing Record 34 of Set 3 | praia
# Processing Record 35 of Set 3 | tasiilaq
# Processing Record 36 of Set 3 | pacifica
# Processing Record 37 of Set 3 | ponta delgada
# Processing Record 38 of Set 3 | saint anthony
# Processing Record 39 of Set 3 | taquara
# Processing Record 40 of Set 3 | varzea da palma
# Processing Record 41 of Set 3 | alofi
# Processing Record 42 of Set 3 | kuito
# Processing Record 43 of Set 3 | sarangani
# Processing Record 44 of Set 3 | prieska
# Processing Record 45 of Set 3 | safford
# Processing Record 46 of Set 3 | geraldton
# Processing Record 47 of Set 3 | metu
# Processing Record 48 of Set 3 | tarauaca
# Processing Record 49 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 50 of Set 3 | college
# Processing Record 1 of Set 4 | okhotsk
# Processing Record 2 of Set 4 | kuvandyk
# Processing Record 3 of Set 4 | darhan
# Processing Record 4 of Set 4 | bocaiuva
# Processing Record 5 of Set 4 | mahanoro
# Processing Record 6 of Set 4 | saint-francois
# Processing Record 7 of Set 4 | souillac
# Processing Record 8 of Set 4 | port alfred
# Processing Record 9 of Set 4 | broome
# Processing Record 10 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 4 | faanui
# Processing Record 12 of Set 4 | dapaong
# Processing Record 13 of Set 4 | uyemskiy
# Processing Record 14 of Set 4 | ucluelet
# Processing Record 15 of Set 4 | busselton
# Processing Record 16 of Set 4 | mirante do paranapanema
# Processing Record 17 of Set 4 | hit
# Processing Record 18 of Set 4 | piacabucu
# Processing Record 19 of Set 4 | am timan
# Processing Record 20 of Set 4 | fortuna
# Processing Record 21 of Set 4 | padilla
# Processing Record 22 of Set 4 | khandyga
# Processing Record 23 of Set 4 | severo-kurilsk
# Processing Record 24 of Set 4 | coihaique
# Processing Record 25 of Set 4 | tahoua
# Processing Record 26 of Set 4 | dunedin
# Processing Record 27 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 28 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 4 | anadyr
# Processing Record 30 of Set 4 | dingle
# Processing Record 31 of Set 4 | liminangcong
# City not found. Skipping...
# Processing Record 32 of Set 4 | buraydah
# Processing Record 33 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 4 | butaritari
# Processing Record 35 of Set 4 | dakar
# Processing Record 36 of Set 4 | korla
# Processing Record 37 of Set 4 | abashiri
# Processing Record 38 of Set 4 | pozo colorado
# Processing Record 39 of Set 4 | cururupu
# Processing Record 40 of Set 4 | guerrero negro
# Processing Record 41 of Set 4 | nefteyugansk
# Processing Record 42 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 4 | pangnirtung
# Processing Record 44 of Set 4 | singapore
# Processing Record 45 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 46 of Set 4 | smidovich
# Processing Record 47 of Set 4 | sao filipe
# Processing Record 48 of Set 4 | escanaba
# Processing Record 49 of Set 4 | tabou
# Processing Record 50 of Set 4 | namatanai
# Processing Record 1 of Set 5 | matay
# Processing Record 2 of Set 5 | tocopilla
# Processing Record 3 of Set 5 | kadykchan
# City not found. Skipping...
# Processing Record 4 of Set 5 | kirakira
# Processing Record 5 of Set 5 | san carlos de bariloche
# Processing Record 6 of Set 5 | mount gambier
# Processing Record 7 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 5 | viedma
# Processing Record 9 of Set 5 | talnakh
# Processing Record 10 of Set 5 | aripuana
# Processing Record 11 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 5 | puerto ayora
# Processing Record 13 of Set 5 | karabuk
# Processing Record 14 of Set 5 | airai
# Processing Record 15 of Set 5 | mount hagen
# Processing Record 16 of Set 5 | temaraia
# City not found. Skipping...
# Processing Record 17 of Set 5 | kichera
# Processing Record 18 of Set 5 | jamsa
# Processing Record 19 of Set 5 | vangaindrano
# Processing Record 20 of Set 5 | jinxiang
# Processing Record 21 of Set 5 | ruangwa
# Processing Record 22 of Set 5 | coihueco
# Processing Record 23 of Set 5 | kuntaur
# Processing Record 24 of Set 5 | port-gentil
# Processing Record 25 of Set 5 | yazman
# Processing Record 26 of Set 5 | shiggaon
# Processing Record 27 of Set 5 | vitry-le-francois
# Processing Record 28 of Set 5 | faya
# Processing Record 29 of Set 5 | caucaia
# Processing Record 30 of Set 5 | mackay
# Processing Record 31 of Set 5 | kanigiri
# Processing Record 32 of Set 5 | nikolskoye
# Processing Record 33 of Set 5 | antofagasta
# Processing Record 34 of Set 5 | hofn
# Processing Record 35 of Set 5 | saskylakh
# Processing Record 36 of Set 5 | padang
# Processing Record 37 of Set 5 | ponta do sol
# Processing Record 38 of Set 5 | mumford
# Processing Record 39 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 5 | tilichiki
# Processing Record 41 of Set 5 | ahipara
# Processing Record 42 of Set 5 | rio gallegos
# Processing Record 43 of Set 5 | makakilo city
# Processing Record 44 of Set 5 | neiafu
# Processing Record 45 of Set 5 | marsa matruh
# Processing Record 46 of Set 5 | kavaratti
# Processing Record 47 of Set 5 | malakal
# Processing Record 48 of Set 5 | tazmalt
# Processing Record 49 of Set 5 | mogadishu
# Processing Record 50 of Set 5 | mikuni
# Processing Record 1 of Set 6 | washington
# Processing Record 2 of Set 6 | aklavik
# Processing Record 3 of Set 6 | melbu
# Processing Record 4 of Set 6 | orahovac
# Processing Record 5 of Set 6 | victor harbor
# Processing Record 6 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 7 of Set 6 | whitehorse
# Processing Record 8 of Set 6 | sheridan
# Processing Record 9 of Set 6 | husavik
# Processing Record 10 of Set 6 | arlit
# Processing Record 11 of Set 6 | santa isabel do rio negro
# Processing Record 12 of Set 6 | laguna
# Processing Record 13 of Set 6 | camopi
# Processing Record 14 of Set 6 | old road
# City not found. Skipping...
# Processing Record 15 of Set 6 | provideniya
# Processing Record 16 of Set 6 | talcahuano
# Processing Record 17 of Set 6 | krutaya gorka
# Processing Record 18 of Set 6 | opuwo
# Processing Record 19 of Set 6 | hastings
# Processing Record 20 of Set 6 | constitucion
# Processing Record 21 of Set 6 | zhigansk
# Processing Record 22 of Set 6 | macomer
# Processing Record 23 of Set 6 | acapulco
# Processing Record 24 of Set 6 | bireun
# Processing Record 25 of Set 6 | cherskiy
# Processing Record 26 of Set 6 | pervomayskoye
# Processing Record 27 of Set 6 | baherden
# Processing Record 28 of Set 6 | benito juarez
# Processing Record 29 of Set 6 | colares
# Processing Record 30 of Set 6 | palembang
# Processing Record 31 of Set 6 | teresopolis
# Processing Record 32 of Set 6 | sao jose da coroa grande
# Processing Record 33 of Set 6 | svarstad
# Processing Record 34 of Set 6 | barrow
# Processing Record 35 of Set 6 | havre-saint-pierre
# Processing Record 36 of Set 6 | ambanja
# Processing Record 37 of Set 6 | mangrol
# Processing Record 38 of Set 6 | san clemente
# Processing Record 39 of Set 6 | saldanha
# Processing Record 40 of Set 6 | preeceville
# Processing Record 41 of Set 6 | mana
# Processing Record 42 of Set 6 | balkhash
# Processing Record 43 of Set 6 | tyn nad vltavou
# Processing Record 44 of Set 6 | bobrovka
# Processing Record 45 of Set 6 | ceyhan
# Processing Record 46 of Set 6 | ambodifototra
# City not found. Skipping...
# Processing Record 47 of Set 6 | shelburne
# Processing Record 48 of Set 6 | karpathos
# Processing Record 49 of Set 6 | north platte
# Processing Record 50 of Set 6 | pisco
# Processing Record 1 of Set 7 | xining
# Processing Record 2 of Set 7 | sobolevo
# Processing Record 3 of Set 7 | salalah
# Processing Record 4 of Set 7 | ambatondrazaka
# Processing Record 5 of Set 7 | gyor
# Processing Record 6 of Set 7 | beruni
# City not found. Skipping...
# Processing Record 7 of Set 7 | svetlaya
# Processing Record 8 of Set 7 | star
# Processing Record 9 of Set 7 | rafaela
# Processing Record 10 of Set 7 | holland
# Processing Record 11 of Set 7 | carman
# Processing Record 12 of Set 7 | honningsvag
# Processing Record 13 of Set 7 | baisha
# Processing Record 14 of Set 7 | new norfolk
# Processing Record 15 of Set 7 | sitka
# Processing Record 16 of Set 7 | ostrovnoy
# Processing Record 17 of Set 7 | kholtoson
# Processing Record 18 of Set 7 | saint-philippe
# Processing Record 19 of Set 7 | los llanos de aridane
# Processing Record 20 of Set 7 | suntar
# Processing Record 21 of Set 7 | kahului
# Processing Record 22 of Set 7 | mutsamudu
# City not found. Skipping...
# Processing Record 23 of Set 7 | sao joao da barra
# Processing Record 24 of Set 7 | itupiranga
# Processing Record 25 of Set 7 | port lincoln
# Processing Record 26 of Set 7 | umm kaddadah
# Processing Record 27 of Set 7 | soyo
# Processing Record 28 of Set 7 | susanville
# Processing Record 29 of Set 7 | acarau
# Processing Record 30 of Set 7 | comodoro rivadavia
# Processing Record 31 of Set 7 | quatre cocos
# Processing Record 32 of Set 7 | mahenge
# Processing Record 33 of Set 7 | babanusah
# City not found. Skipping...
# Processing Record 34 of Set 7 | yunjinghong
# City not found. Skipping...
# Processing Record 35 of Set 7 | bethel
# Processing Record 36 of Set 7 | bubaque
# Processing Record 37 of Set 7 | kavieng
# Processing Record 38 of Set 7 | orchard homes
# Processing Record 39 of Set 7 | bonfim
# Processing Record 40 of Set 7 | zanatepec
# City not found. Skipping...
# Processing Record 41 of Set 7 | bosaso
# Processing Record 42 of Set 7 | aksehir
# Processing Record 43 of Set 7 | paragominas
# Processing Record 44 of Set 7 | nemuro
# Processing Record 45 of Set 7 | juneau
# Processing Record 46 of Set 7 | sur
# Processing Record 47 of Set 7 | gobabis
# Processing Record 48 of Set 7 | vestmanna
# Processing Record 49 of Set 7 | tiksi
# Processing Record 50 of Set 7 | dali
# Processing Record 1 of Set 8 | shubarshi
# Processing Record 2 of Set 8 | san patricio
# Processing Record 3 of Set 8 | mnogovershinnyy
# Processing Record 4 of Set 8 | bay roberts
# Processing Record 5 of Set 8 | ayna
# Processing Record 6 of Set 8 | broken hill
# Processing Record 7 of Set 8 | marzuq
# Processing Record 8 of Set 8 | lichtenstein
# Processing Record 9 of Set 8 | sundargarh
# Processing Record 10 of Set 8 | hammerfest
# Processing Record 11 of Set 8 | puerto escondido
# Processing Record 12 of Set 8 | northam
# Processing Record 13 of Set 8 | tabuk
# Processing Record 14 of Set 8 | banda aceh
# Processing Record 15 of Set 8 | reconquista
# Processing Record 16 of Set 8 | koulamoutou
# Processing Record 17 of Set 8 | selikhino
# Processing Record 18 of Set 8 | vila velha
# Processing Record 19 of Set 8 | avera
# Processing Record 20 of Set 8 | sumbawa
# City not found. Skipping...
# Processing Record 21 of Set 8 | fevralsk
# City not found. Skipping...
# Processing Record 22 of Set 8 | abnub
# Processing Record 23 of Set 8 | beni mazar
# Processing Record 24 of Set 8 | sao felix do xingu
# Processing Record 25 of Set 8 | dhoraji
# Processing Record 26 of Set 8 | burnie
# Processing Record 27 of Set 8 | urucara
# Processing Record 28 of Set 8 | saint george
# Processing Record 29 of Set 8 | evensk
# Processing Record 30 of Set 8 | komsomolskiy
# Processing Record 31 of Set 8 | skjervoy
# Processing Record 32 of Set 8 | sulina
# Processing Record 33 of Set 8 | santa maria
# Processing Record 34 of Set 8 | chuy
# Processing Record 35 of Set 8 | porto novo
# Processing Record 36 of Set 8 | burica
# City not found. Skipping...
# Processing Record 37 of Set 8 | alice springs
# Processing Record 38 of Set 8 | skalistyy
# City not found. Skipping...
# Processing Record 39 of Set 8 | saraza
# Processing Record 40 of Set 8 | tutoia
# Processing Record 41 of Set 8 | lavrentiya
# Processing Record 42 of Set 8 | nanortalik
# Processing Record 43 of Set 8 | iranshahr
# Processing Record 44 of Set 8 | tezu
# Processing Record 45 of Set 8 | laredo
# Processing Record 46 of Set 8 | bhatkal
# Processing Record 47 of Set 8 | belluno
# Processing Record 48 of Set 8 | torbay
# Processing Record 49 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 50 of Set 8 | malaut
# Processing Record 1 of Set 9 | thai binh
# Processing Record 2 of Set 9 | la romana
# Processing Record 3 of Set 9 | tautira
# Processing Record 4 of Set 9 | qinhuangdao
# Processing Record 5 of Set 9 | puerto suarez
# Processing Record 6 of Set 9 | amapa
# Processing Record 7 of Set 9 | sorland
# Processing Record 8 of Set 9 | tahe
# Processing Record 9 of Set 9 | bilibino
# Processing Record 10 of Set 9 | emba
# Processing Record 11 of Set 9 | upington
# Processing Record 12 of Set 9 | bolshiye kaybitsy
# City not found. Skipping...
# Processing Record 13 of Set 9 | bukama
# Processing Record 14 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 9 | lazaro cardenas
# Processing Record 16 of Set 9 | alihe
# Processing Record 17 of Set 9 | srandakan
# Processing Record 18 of Set 9 | narsaq
# Processing Record 19 of Set 9 | heilbron
# Processing Record 20 of Set 9 | ketchikan
# Processing Record 21 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 22 of Set 9 | dubna
# Processing Record 23 of Set 9 | villa carlos paz
# Processing Record 24 of Set 9 | aksu
# Processing Record 25 of Set 9 | kingsport
# Processing Record 26 of Set 9 | ocos
# Processing Record 27 of Set 9 | lodwar
# Processing Record 28 of Set 9 | benalla
# Processing Record 29 of Set 9 | sibolga
# Processing Record 30 of Set 9 | xunchang
# Processing Record 31 of Set 9 | bereda
# Processing Record 32 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 9 | aykhal
# Processing Record 34 of Set 9 | nara
# Processing Record 35 of Set 9 | dujuma
# City not found. Skipping...
# Processing Record 36 of Set 9 | muros
# Processing Record 37 of Set 9 | kushiro
# Processing Record 38 of Set 9 | shahreza
# Processing Record 39 of Set 9 | leon valley
# Processing Record 40 of Set 9 | nipawin
# Processing Record 41 of Set 9 | wasilla
# Processing Record 42 of Set 9 | kaitangata
# Processing Record 43 of Set 9 | luau
# Processing Record 44 of Set 9 | luwuk
# Processing Record 45 of Set 9 | gulu
# Processing Record 46 of Set 9 | vila franca do campo
# Processing Record 47 of Set 9 | hami
# Processing Record 48 of Set 9 | tawang
# Processing Record 49 of Set 9 | bermeo
# Processing Record 50 of Set 9 | nouadhibou
# Processing Record 1 of Set 10 | consuegra
# Processing Record 2 of Set 10 | henties bay
# Processing Record 3 of Set 10 | ekhabi
# Processing Record 4 of Set 10 | rio claro
# Processing Record 5 of Set 10 | maragogi
# Processing Record 6 of Set 10 | cardston
# Processing Record 7 of Set 10 | the valley
# Processing Record 8 of Set 10 | sanandaj
# Processing Record 9 of Set 10 | hovd
# Processing Record 10 of Set 10 | san pedro
# Processing Record 11 of Set 10 | san cristobal
# Processing Record 12 of Set 10 | srednekolymsk
# Processing Record 13 of Set 10 | lagunas
# Processing Record 14 of Set 10 | uray
# Processing Record 15 of Set 10 | caudry
# Processing Record 16 of Set 10 | touros
# Processing Record 17 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 18 of Set 10 | payo
# Processing Record 19 of Set 10 | urma
# Processing Record 20 of Set 10 | pamfila
# Processing Record 21 of Set 10 | eyl
# Processing Record 22 of Set 10 | bambous virieux
# Processing Record 23 of Set 10 | oranjemund
# Processing Record 24 of Set 10 | omboue
# Processing Record 25 of Set 10 | kendari
# Processing Record 26 of Set 10 | kargasok
# Processing Record 27 of Set 10 | perugia
# Processing Record 28 of Set 10 | nuuk
# Processing Record 29 of Set 10 | pareora
# Processing Record 30 of Set 10 | tena
# Processing Record 31 of Set 10 | dinan
# Processing Record 32 of Set 10 | marienburg
# Processing Record 33 of Set 10 | asosa
# Processing Record 34 of Set 10 | calipan
# Processing Record 35 of Set 10 | crotone
# Processing Record 36 of Set 10 | maceio
# Processing Record 37 of Set 10 | matadi
# Processing Record 38 of Set 10 | tougan
# Processing Record 39 of Set 10 | pietarsaari
# Processing Record 40 of Set 10 | seohara
# Processing Record 41 of Set 10 | loviisa
# Processing Record 42 of Set 10 | luanda
# Processing Record 43 of Set 10 | makungu
# Processing Record 44 of Set 10 | gamba
# Processing Record 45 of Set 10 | princeton
# Processing Record 46 of Set 10 | erzin
# Processing Record 47 of Set 10 | malumfashi
# Processing Record 48 of Set 10 | chicama
# Processing Record 49 of Set 10 | savannakhet
# Processing Record 50 of Set 10 | hambantota
# Processing Record 1 of Set 11 | bairiki
# Processing Record 2 of Set 11 | walvis bay
# Processing Record 3 of Set 11 | mbaiki
# Processing Record 4 of Set 11 | alibag
# Processing Record 5 of Set 11 | ruzomberok
# Processing Record 6 of Set 11 | berlevag
# Processing Record 7 of Set 11 | santa rosa
# Processing Record 8 of Set 11 | najran
# Processing Record 9 of Set 11 | takoradi
# Processing Record 10 of Set 11 | cochrane
# Processing Record 11 of Set 11 | novosysoyevka
# Processing Record 12 of Set 11 | okha
# Processing Record 13 of Set 11 | san jose
# Processing Record 14 of Set 11 | buala
# Processing Record 15 of Set 11 | evanston
# Processing Record 16 of Set 11 | sedalia
# Processing Record 17 of Set 11 | ambulu
# Processing Record 18 of Set 11 | kilrush
# Processing Record 19 of Set 11 | abramovka
# Processing Record 20 of Set 11 | hobyo
# Processing Record 21 of Set 11 | lingolsheim
# Processing Record 22 of Set 11 | rafai
# Processing Record 23 of Set 11 | lagawe
# Processing Record 24 of Set 11 | obidos
# Processing Record 25 of Set 11 | galle
# Processing Record 26 of Set 11 | griffith
# Processing Record 27 of Set 11 | vila do maio
# Processing Record 28 of Set 11 | dhidhdhoo
# Processing Record 29 of Set 11 | kundiawa
# Processing Record 30 of Set 11 | nantucket
# Processing Record 31 of Set 11 | waipawa
# Processing Record 32 of Set 11 | deputatskiy
# Processing Record 33 of Set 11 | chumikan
# Processing Record 34 of Set 11 | bandar-e lengeh
# Processing Record 35 of Set 11 | eaton socon
# Processing Record 36 of Set 11 | shitanjing
# Processing Record 37 of Set 11 | akureyri
# Processing Record 38 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 39 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 40 of Set 11 | riyadh
# Processing Record 41 of Set 11 | chikoy
# City not found. Skipping...
# Processing Record 42 of Set 11 | kramat
# Processing Record 43 of Set 11 | raga
# Processing Record 44 of Set 11 | mahanje
# Processing Record 45 of Set 11 | pringsewu
# Processing Record 46 of Set 11 | andros town
# Processing Record 47 of Set 11 | misratah
# Processing Record 48 of Set 11 | fairbanks
# Processing Record 49 of Set 11 | bolshiye uki
# City not found. Skipping...
# Processing Record 50 of Set 11 | fernie
# Processing Record 1 of Set 12 | thinadhoo
# Processing Record 2 of Set 12 | jega
# Processing Record 3 of Set 12 | worland
# Processing Record 4 of Set 12 | tartagal
# Processing Record 5 of Set 12 | bam
# Processing Record 6 of Set 12 | harrison
# Processing Record 7 of Set 12 | miranorte
# City not found. Skipping...
# Processing Record 8 of Set 12 | gainesville
# Processing Record 9 of Set 12 | yerbogachen
# Processing Record 10 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 11 of Set 12 | pingxiang
# Processing Record 12 of Set 12 | veraval
# Processing Record 13 of Set 12 | margate
# Processing Record 14 of Set 12 | ewa beach
# Processing Record 15 of Set 12 | angoche
# Processing Record 16 of Set 12 | kieta
# Processing Record 17 of Set 12 | ust-tsilma
# Processing Record 18 of Set 12 | tadine
# Processing Record 19 of Set 12 | gibara
# Processing Record 20 of Set 12 | espanola
# Processing Record 21 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 22 of Set 12 | merrill
# Processing Record 23 of Set 12 | aswan
# Processing Record 24 of Set 12 | townsville
# Processing Record 25 of Set 12 | beloha
# Processing Record 26 of Set 12 | sirfa
# City not found. Skipping...
# Processing Record 27 of Set 12 | cobija
# Processing Record 28 of Set 12 | rassvet
# Processing Record 29 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 30 of Set 12 | troitsko-pechorsk
# Processing Record 31 of Set 12 | svay rieng
# Processing Record 32 of Set 12 | vao
# Processing Record 33 of Set 12 | anchorage
# Processing Record 34 of Set 12 | palampur
# Processing Record 35 of Set 12 | kailua
# Processing Record 36 of Set 12 | tubruq
# City not found. Skipping...
# Processing Record 37 of Set 12 | wagar
# Processing Record 38 of Set 12 | rabo de peixe
# Processing Record 39 of Set 12 | moroni
# Processing Record 40 of Set 12 | beipiao
# Processing Record 41 of Set 12 | madang
# Processing Record 42 of Set 12 | batticaloa
# Processing Record 43 of Set 12 | danville
# Processing Record 44 of Set 12 | san vicente
# Processing Record 45 of Set 12 | tapaua
# City not found. Skipping...
# Processing Record 46 of Set 12 | belyy yar
# Processing Record 47 of Set 12 | auka
# Processing Record 48 of Set 12 | leningradskiy
# Processing Record 49 of Set 12 | katha
# City not found. Skipping...
# Processing Record 50 of Set 12 | gravdal
# Processing Record 1 of Set 13 | stillwater
# Processing Record 2 of Set 13 | tura
# Processing Record 3 of Set 13 | cazaje
# City not found. Skipping...
# Processing Record 4 of Set 13 | amos
# Processing Record 5 of Set 13 | wattegama
# Processing Record 6 of Set 13 | saint-pierre
# Processing Record 7 of Set 13 | shimoda
# Processing Record 8 of Set 13 | portree
# Processing Record 9 of Set 13 | sinnamary
# Processing Record 10 of Set 13 | ambon
# Processing Record 11 of Set 13 | pericos
# Processing Record 12 of Set 13 | gizo
# Processing Record 13 of Set 13 | potam
# Processing Record 14 of Set 13 | sofiysk
# City not found. Skipping...
# Processing Record 15 of Set 13 | klyuchi
# Processing Record 16 of Set 13 | luderitz
# Processing Record 17 of Set 13 | boende
# Processing Record 18 of Set 13 | penapolis
# Processing Record 19 of Set 13 | nabire
# Processing Record 20 of Set 13 | itapaci
# Processing Record 21 of Set 13 | nizhniy kuranakh
# Processing Record 22 of Set 13 | yarada
# Processing Record 23 of Set 13 | grindavik
# Processing Record 24 of Set 13 | culpeper
# Processing Record 25 of Set 13 | batemans bay
# Processing Record 26 of Set 13 | rovaniemi
# Processing Record 27 of Set 13 | christchurch
# Processing Record 28 of Set 13 | hoquiam
# Processing Record 29 of Set 13 | port macquarie
# Processing Record 30 of Set 13 | sonoita
# Processing Record 31 of Set 13 | pelotas
# Processing Record 32 of Set 13 | horta
# Processing Record 33 of Set 13 | tomatlan
# Processing Record 34 of Set 13 | alta floresta
# Processing Record 35 of Set 13 | bintulu
# Processing Record 36 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 37 of Set 13 | san juan de la maguana
# Processing Record 38 of Set 13 | bulgan
# Processing Record 39 of Set 13 | gisborne
# Processing Record 40 of Set 13 | tiznit
# Processing Record 41 of Set 13 | bilsanda
# Processing Record 42 of Set 13 | flinders
# Processing Record 43 of Set 13 | taltal
# Processing Record 44 of Set 13 | kralendijk
# Processing Record 45 of Set 13 | kamsack
# Processing Record 46 of Set 13 | sawtell
# Processing Record 47 of Set 13 | zhuhai
# Processing Record 48 of Set 13 | caravelas
# Processing Record 49 of Set 13 | odesskoye
# Processing Record 50 of Set 13 | kayasula
# Processing Record 1 of Set 14 | jacareacanga
# Processing Record 2 of Set 14 | rhyl
# Processing Record 3 of Set 14 | kerman
# Processing Record 4 of Set 14 | russell
# Processing Record 5 of Set 14 | ambunti
# Processing Record 6 of Set 14 | solnechnyy
# Processing Record 7 of Set 14 | taoudenni
# Processing Record 8 of Set 14 | jalu
# Processing Record 9 of Set 14 | ossora
# Processing Record 10 of Set 14 | ust-maya
# Processing Record 11 of Set 14 | ribnica
# Processing Record 12 of Set 14 | presidencia roque saenz pena
# Processing Record 13 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 14 of Set 14 | tasbuget
# City not found. Skipping...
# Processing Record 15 of Set 14 | ustka
# Processing Record 16 of Set 14 | gazli
# Processing Record 17 of Set 14 | balkanabat
# Processing Record 18 of Set 14 | praia da vitoria
# Processing Record 19 of Set 14 | kukmor
# Processing Record 20 of Set 14 | paris
# Processing Record 21 of Set 14 | kodinsk
# Processing Record 22 of Set 14 | raha
# Processing Record 23 of Set 14 | mount isa
# Processing Record 24 of Set 14 | kottapalli
# Processing Record 25 of Set 14 | santa rosalia
# Processing Record 26 of Set 14 | bougouni
# Processing Record 27 of Set 14 | bose
# Processing Record 28 of Set 14 | methoni
# Processing Record 29 of Set 14 | alanib
# Processing Record 30 of Set 14 | lakes entrance
# Processing Record 31 of Set 14 | torquay
# Processing Record 32 of Set 14 | great yarmouth
# Processing Record 33 of Set 14 | surt
# Processing Record 34 of Set 14 | jermuk
# Processing Record 35 of Set 14 | mbour
# Processing Record 36 of Set 14 | florianopolis
# Processing Record 37 of Set 14 | nioro
# Processing Record 38 of Set 14 | porbandar
# Processing Record 39 of Set 14 | atasu
# Processing Record 40 of Set 14 | syracuse
# City not found. Skipping...
# Processing Record 41 of Set 14 | rock sound
# Processing Record 42 of Set 14 | baltasi
# Processing Record 43 of Set 14 | adre
# Processing Record 44 of Set 14 | saint-louis
# Processing Record 45 of Set 14 | woodstock
# Processing Record 46 of Set 14 | vanimo
# Processing Record 47 of Set 14 | peleduy
# Processing Record 48 of Set 14 | tupik
# Processing Record 49 of Set 14 | gorgan
# Processing Record 50 of Set 14 | bahia blanca
# Processing Record 1 of Set 15 | richards bay
# Processing Record 2 of Set 15 | vanderhoof
# Processing Record 3 of Set 15 | la ronge
# Processing Record 4 of Set 15 | nkongsamba
# Processing Record 5 of Set 15 | shchelyayur
# City not found. Skipping...
# Processing Record 6 of Set 15 | high rock
# Processing Record 7 of Set 15 | progreso
# Processing Record 8 of Set 15 | qasigiannguit
# Processing Record 9 of Set 15 | makambako
# Processing Record 10 of Set 15 | blackwater
# Processing Record 11 of Set 15 | tarko-sale
# Processing Record 12 of Set 15 | mizdah
# Processing Record 13 of Set 15 | ixtapa
# Processing Record 14 of Set 15 | awbari
# Processing Record 15 of Set 15 | karasuk
# Processing Record 16 of Set 15 | ye
# City not found. Skipping...
# Processing Record 17 of Set 15 | mezen
# Processing Record 18 of Set 15 | palmas
# Processing Record 19 of Set 15 | sarakhs
# Processing Record 20 of Set 15 | jiddah
# City not found. Skipping...
# Processing Record 21 of Set 15 | zeya
# Processing Record 22 of Set 15 | rupert
# Processing Record 23 of Set 15 | ferrol
# Processing Record 24 of Set 15 | kapoeta
# Processing Record 25 of Set 15 | pontian kecil
# Processing Record 26 of Set 15 | mabaruma
# Processing Record 27 of Set 15 | palaikastron
# Processing Record 28 of Set 15 | saint-ambroise
# Processing Record 29 of Set 15 | romans-sur-isere
# Processing Record 30 of Set 15 | poya
# Processing Record 31 of Set 15 | lawrenceburg
# Processing Record 32 of Set 15 | namibe
# Processing Record 33 of Set 15 | houston
# Processing Record 34 of Set 15 | tooele
# Processing Record 35 of Set 15 | sayyan
# Processing Record 36 of Set 15 | udachnyy
# Processing Record 37 of Set 15 | flums
# Processing Record 38 of Set 15 | asau
# Processing Record 39 of Set 15 | katsuura
# Processing Record 40 of Set 15 | cap-aux-meules
# Processing Record 41 of Set 15 | gorontalo
# Processing Record 42 of Set 15 | kanel
# Processing Record 43 of Set 15 | lata
# Processing Record 44 of Set 15 | jardim
# Processing Record 45 of Set 15 | tolstoy-yurt
# Processing Record 46 of Set 15 | pangkalanbuun
# Processing Record 47 of Set 15 | marsh harbour
# Processing Record 48 of Set 15 | hasaki
# Processing Record 49 of Set 15 | sataua
# City not found. Skipping...
# Processing Record 50 of Set 15 | vicuna
# Processing Record 1 of Set 16 | belmonte
# Processing Record 2 of Set 16 | edeia
# Processing Record 3 of Set 16 | sharlyk
# Processing Record 4 of Set 16 | port hedland
# Processing Record 5 of Set 16 | hibbing
# Processing Record 6 of Set 16 | ararangua
# Processing Record 7 of Set 16 | auki
# Processing Record 8 of Set 16 | finschhafen
# Processing Record 9 of Set 16 | hede
# Processing Record 10 of Set 16 | miraflores
# Processing Record 11 of Set 16 | samalaeulu
# City not found. Skipping...
# Processing Record 12 of Set 16 | rio cuarto
# Processing Record 13 of Set 16 | necochea
# Processing Record 14 of Set 16 | saiha
# Processing Record 15 of Set 16 | jensen beach
# Processing Record 16 of Set 16 | kyzyl-suu
# Processing Record 17 of Set 16 | ennis
# Processing Record 18 of Set 16 | kuytun
# Processing Record 19 of Set 16 | port blair
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 706

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.

city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#             City      Lat       Lng   Temp  Min Temp  Max Temp  Humidity  \
# 0      Bathsheba  13.2167  -59.5167  81.21     81.21     81.21        69
# 1       Cidreira -30.1811  -50.2056  69.33     69.33     69.33        88
# 2        Emerald -23.5333  148.1667  82.35     82.35     82.35        66
# 3      Cape Town -33.9258   18.4232  64.08     60.35     67.37        72
# 4  Batagay-Alyta  67.8006  130.4114 -28.25    -28.25    -28.25        98
# 5           Kaeo -35.1000  173.7833  70.32     70.32     70.32        65
# 6         Castro -24.7911  -50.0119  58.78     58.78     58.78        98
# 7           Lebu -37.6167  -73.6500  54.77     54.77     54.77        92
# 8        Rikitea -23.1203 -134.9692  75.61     75.61     75.61        73
# 9       Goderich  43.7501  -81.7165  39.52     39.52     42.91        93
#
#    Cloudiness  Wind Speed Current Description   Current Details Country  \
# 0          40       20.71              Clouds  scattered clouds      BB
# 1           3       14.72               Clear         clear sky      BR
# 2         100       10.04                Rain        light rain      AU
# 3           0        5.75               Clear         clear sky      ZA
# 4          91        3.00              Clouds   overcast clouds      RU
# 5         100       10.83              Clouds   overcast clouds      NZ
# 6          99        9.71              Clouds   overcast clouds      BR
# 7           4        9.28               Clear         clear sky      CL
# 8          21        7.52              Clouds        few clouds      PF
# 9          97       10.36              Clouds   overcast clouds      CA
#
#                   Date
# 0  2022-11-28 03:58:21
# 1  2022-11-28 03:58:21
# 2  2022-11-28 03:58:22
# 3  2022-11-28 03:57:35
# 4  2022-11-28 03:58:23
# 5  2022-11-28 03:58:24
# 6  2022-11-28 03:58:25
# 7  2022-11-28 03:58:25
# 8  2022-11-28 03:58:26
# 9  2022-11-28 03:58:27

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Temp', 'Min Temp', 'Max Temp', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Current Description', 'Current Details',
#        'Country', 'Date'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
updated_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[updated_column_order]
# Display sample data
city_data_df
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Bathsheba      BB  13.2167  -59.5167     81.21        69          40
# 1         Cidreira      BR -30.1811  -50.2056     69.33        88           3
# 2          Emerald      AU -23.5333  148.1667     82.35        66         100
# 3        Cape Town      ZA -33.9258   18.4232     67.37        72           0
# 4    Batagay-Alyta      RU  67.8006  130.4114    -28.25        98          91
# ..             ...     ...      ...       ...       ...       ...         ...
# 701   Jensen Beach      US  27.2545  -80.2298     76.08        86           0
# 702      Kyzyl-Suu      KG  42.3414   78.0056     31.82        57          32
# 703          Ennis      IE  52.8436   -8.9864     46.33        87          75
# 704         Kuytun      RU  54.3419  101.5036     -5.55        85         100
# 705     Port Blair      IN  11.6667   92.7500     86.04        70          20
#
#      Wind Speed Current Description
# 0         20.71              Clouds
# 1         14.72               Clear
# 2         10.04                Rain
# 3          5.75               Clear
# 4          3.00              Clouds
# ..          ...                 ...
# 701        5.75               Clear
# 702        3.13              Clouds
# 703       12.66              Clouds
# 704       11.56              Clouds
# 705        4.61              Clouds
#
# [706 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
